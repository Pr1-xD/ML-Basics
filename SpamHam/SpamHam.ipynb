# %% [markdown]
# Importing packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Importing Dataset

# %%
import os
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-fcf50daf-4f64-49f4-bd75-a02785a85e59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcf50daf-4f64-49f4-bd75-a02785a85e59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_features.csv to test_features.csv
# Saving train_data.csv to train_data.csv

# %% [markdown]
# Load .csv file into a DataFrame

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['train_data.csv']))
dftest = pd.read_csv(io.BytesIO(uploaded['test_features.csv']))

# %% [markdown]
# Display Dataframe

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  ...    ham    Id
# 0             0.0              14.28  ...   True  1947
# 1             0.0               0.00  ...  False  2159
# 2             0.0               0.00  ...  False  4223
# 3             0.0               0.00  ...   True  2624
# 4             0.0               0.00  ...   True  2743
#
# [5 rows x 59 columns]

# %% [markdown]
# Dataset Stats

# %%
df.describe()
# Out:
#        word_freq_make  word_freq_address  ...  capital_run_length_total           Id
# count     3680.000000        3680.000000  ...               3680.000000  3680.000000
# mean         0.099677           0.223353  ...                283.316304  2297.439674
# std          0.298270           1.337420  ...                623.433481  1324.109165
# min          0.000000           0.000000  ...                  1.000000     0.000000
# 25%          0.000000           0.000000  ...                 34.000000  1160.750000
# 50%          0.000000           0.000000  ...                 93.000000  2298.000000
# 75%          0.000000           0.000000  ...                270.500000  3445.250000
# max          4.540000          14.280000  ...              15841.000000  4600.000000
#
# [8 rows x 58 columns]

# %% [markdown]
# Label Encoding for the string values

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df.ham=le.fit_transform(df.ham)

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  ...  ham    Id
# 0             0.0              14.28  ...    1  1947
# 1             0.0               0.00  ...    0  2159
# 2             0.0               0.00  ...    0  4223
# 3             0.0               0.00  ...    1  2624
# 4             0.0               0.00  ...    1  2743
#
# [5 rows x 59 columns]

# %% [markdown]
# Splitting dataset into features and output

# %%
X = df.drop(['ham','Id'], axis=1)
y = df['ham']

# %% [markdown]
# Standardizing Data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
scaled_data = scaler.transform(X)
scaled_data = pd.DataFrame(scaled_data, columns= X.columns)
scaled_data.head()
# Out:
#    word_freq_make  ...  capital_run_length_total
# 0       -0.334228  ...                 -0.440069
# 1       -0.334228  ...                 -0.178578
# 2       -0.334228  ...                 -0.350231
# 3       -0.334228  ...                 -0.409588
# 4       -0.334228  ...                 -0.382316
#
# [5 rows x 57 columns]

# %% [markdown]
# Splitting dataset into training data and testing data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(scaled_data,y, train_size=0.8,random_state=0)

# %% [markdown]
# Applying Logistic Regression and checking score

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=2000)
logreg.fit(X_train, y_train)
print(logreg.score(X_test,y_test))
# Out:
# 0.9144021739130435

# %% [markdown]
# Displaying Confusion Matrix

# %%
y_pred=logreg.predict(X_test)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred, y_test)
# Out:
# array([[243,  32],
#        [ 31, 430]])
